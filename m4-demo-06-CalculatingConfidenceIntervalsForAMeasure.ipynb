# %%
import scipy
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
housing_data = pd.read_csv('datasets/house_data_processed.csv')

housing_data.head()
# Out:
#      ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  LSTAT  \
# 0  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3   4.98
# 1   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8   9.14
# 2   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8   4.03
# 3   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7   2.94
# 4   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7   5.21
#
#    MEDV  above_median
# 0  24.0             1
# 1  21.6             1
# 2  34.7             1
# 3  33.4             1
# 4  28.7             1

# %%
housing_data.shape
# Out:
# (413, 13)

# %%
plt.figure(figsize=(12, 8))

sns.boxplot(x='MEDV', data=housing_data, orient='v')

plt.show()
# Out:
# /Users/williamcepeda/Library/CloudStorage/OneDrive-Personal/Objectel/DataAnalytics/PS_Interpreting_Data_Descriptive_statistics/.venv/lib/python3.14/site-packages/seaborn/_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
plt.figure(figsize=(12, 8))

sns.distplot(housing_data['MEDV'], rug=True, hist=False)

plt.show()
# Out:
# /var/folders/kf/t7svy06102v8d9ht_qv5gpt40000gn/T/ipykernel_74113/3277131046.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(housing_data['MEDV'], rug=True, hist=False)

# %%
mean = np.mean(housing_data['MEDV'])
std = np.std(housing_data['MEDV'])

# %%
mean, std
# Out:
# (22.52639225181601, 9.25273107047878)

# %% [markdown]
# #### For 68% confidence Interval

# %%
conf_int_low, conf_int_high = scipy.stats.norm.interval(0.68, loc=mean, scale=std)

conf_int_low, conf_int_high
# Out:
# (np.float64(13.324940897558538), np.float64(31.727843606073428))

# %%
plt.figure(figsize=(12, 8))

sns.distplot(housing_data['MEDV'], rug=True, kde=True, hist=False)

plt.stem([mean], 
         [0.06], linefmt = 'C1', 
         markerfmt = 'C1', label = 'mean', use_line_collection=True)

plt.stem([conf_int_low], 
         [0.06], linefmt = 'C2', 
         markerfmt = 'C2', label = '95% CI High', use_line_collection=True)

plt.stem([conf_int_high], 
         [0.06], linefmt = 'C3', 
         markerfmt = 'C3', label = '95% CI Low', use_line_collection=True)

plt.xlabel('MEDV')
plt.legend()
plt.show()
# Out:
# /var/folders/kf/t7svy06102v8d9ht_qv5gpt40000gn/T/ipykernel_74113/2303221260.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(housing_data['MEDV'], rug=True, kde=True, hist=False)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 plt.figure(figsize=(12, 8))
#       3 sns.distplot(housing_data['MEDV'], rug=True, kde=True, hist=False)
# ----> 5 plt.stem([mean],
#       6          [0.06], linefmt = 'C1',
#       7          markerfmt = 'C1', label = 'mean', use_line_collection=True)
#       9 plt.stem([conf_int_low],
#      10          [0.06], linefmt = 'C2',
#      11          markerfmt = 'C2', label = '95% CI High', use_line_collection=True)
#      13 plt.stem([conf_int_high],
#      14          [0.06], linefmt = 'C3',
#      15          markerfmt = 'C3', label = '95% CI Low', use_line_collection=True)
#
# TypeError: stem() got an unexpected keyword argument 'use_line_collection'

# %% [markdown]
# ### For 90% confidence interval

# %%
conf_int_low, conf_int_high = scipy.stats.norm.interval(0.90, loc=mean, scale=std)

conf_int_low, conf_int_high
# Out:
# (np.float64(7.307003991332374), np.float64(37.745780512299575))

# %%
plt.figure(figsize=(12, 8))

sns.distplot(housing_data['MEDV'], rug=True, kde=True, hist=False)

plt.stem([mean], 
         [0.06], linefmt = 'C1', 
         markerfmt = 'C1', label = 'mean', use_line_collection=True)

plt.stem([conf_int_low], 
         [0.06], linefmt = 'C2', 
         markerfmt = 'C2', label = '95% CI High', use_line_collection=True)

plt.stem([conf_int_high], 
         [0.06], linefmt = 'C3', 
         markerfmt = 'C3', label = '95% CI Low', use_line_collection=True)

plt.xlabel('MEDV')
plt.legend()
plt.show()
# Out:
# /var/folders/kf/t7svy06102v8d9ht_qv5gpt40000gn/T/ipykernel_74113/2303221260.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(housing_data['MEDV'], rug=True, kde=True, hist=False)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 plt.figure(figsize=(12, 8))
#       3 sns.distplot(housing_data['MEDV'], rug=True, kde=True, hist=False)
# ----> 5 plt.stem([mean],
#       6          [0.06], linefmt = 'C1',
#       7          markerfmt = 'C1', label = 'mean', use_line_collection=True)
#       9 plt.stem([conf_int_low],
#      10          [0.06], linefmt = 'C2',
#      11          markerfmt = 'C2', label = '95% CI High', use_line_collection=True)
#      13 plt.stem([conf_int_high],
#      14          [0.06], linefmt = 'C3',
#      15          markerfmt = 'C3', label = '95% CI Low', use_line_collection=True)
#
# TypeError: stem() got an unexpected keyword argument 'use_line_collection'
