# %% [markdown]
# ## Univariate and Bivariate Analysis

# %% [markdown]
# <b>Dataset</b>: https://www.kaggle.com/mustafaali96/weight-height

# %% [markdown]
# The variables used are:
#     * Height
#     * Weight
#     * Gender

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
import scipy.stats as stats

# %%
# !pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.17.0-cp314-cp314-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in ./.venv/lib/python3.14/site-packages (from scipy) (2.4.1)
# Downloading scipy-1.17.0-cp314-cp314-macosx_14_0_arm64.whl (20.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 36.9 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: scipy
# Successfully installed scipy-1.17.0

# %% [markdown]
# ### Load and read dataset

# %%
data = pd.read_csv('datasets/weight-height.csv')

data.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
data.shape
# Out:
# (10000, 3)

# %% [markdown]
# ### Mean, median, mode, min, max and quantiles

# %%
data.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# #### Gender count

# %%
sns.countplot(data['Gender'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Considering only Height

# %%
height = data['Height']

height.head()
# Out:
# 0    73.847017
# 1    68.781904
# 2    74.110105
# 3    71.730978
# 4    69.881796
# Name: Height, dtype: float64

# %%
height.shape
# Out:
# (10000,)

# %% [markdown]
# #### Histogram-plot

# %%
plt.figure(figsize=(12, 8))

height.plot(kind = 'hist',
            title = 'Height Histogram')
# Out:
# <Axes: title={'center': 'Height Histogram'}, ylabel='Frequency'>

# %% [markdown]
# #### Box-plot

# %%
plt.figure(figsize=(10, 6))

height.plot(kind = 'box',
            title = 'Height Box-plot')
# Out:
# <Axes: title={'center': 'Height Box-plot'}>

# %% [markdown]
# #### KDE distribution for height

# %%
height.plot(kind = 'kde',
            title = 'Height KDE', figsize=(10, 7))
# Out:
# <Axes: title={'center': 'Height KDE'}, ylabel='Density'>

# %% [markdown]
# #### Analysis

# %% [markdown]
# As we can see we have a high count for height in the range 60 to 75.

# %% [markdown]
# ### Considering only weight

# %%
weight = data['Weight']

weight.head()
# Out:
# 0    241.893563
# 1    162.310473
# 2    212.740856
# 3    220.042470
# 4    206.349801
# Name: Weight, dtype: float64

# %%
weight.shape
# Out:
# (10000,)

# %% [markdown]
# #### Histogram-plot

# %%
plt.figure(figsize=(12, 8))

weight.plot(kind = 'hist',
            title = 'Weight Histogram')
# Out:
# <Axes: title={'center': 'Weight Histogram'}, ylabel='Frequency'>

# %% [markdown]
# #### Box-plot

# %%
plt.figure(figsize=(12, 8))

weight.plot(kind = 'box',
            title = 'Weight Box-plot')
# Out:
# <Axes: title={'center': 'Weight Box-plot'}>

# %% [markdown]
# #### KDE distribution for height

# %%
plt.figure(figsize=(10, 6))

weight.plot(kind = 'kde',
            title = 'Weight KDE')
# Out:
# <Axes: title={'center': 'Weight KDE'}, ylabel='Density'>

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# #### Considering both height and weight

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(x = "Height", y = "Weight", data=data)
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(x = "Height", y = "Weight", hue='Gender', data=data)
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
gender_groupby = data.groupby('Gender', as_index=False)

gender_groupby.head()
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# 5000  Female  58.910732  102.088326
# 5001  Female  65.230013  141.305823
# 5002  Female  63.369004  131.041403
# 5003  Female  64.479997  128.171511
# 5004  Female  61.793096  129.781407

# %%
gender_groupby.describe()
# Out:
#    Gender  Height                                                        \
#             count       mean       std        min        25%        50%
# 0  Female  5000.0  63.708774  2.696284  54.263133  61.894441  63.730924
# 1    Male  5000.0  69.026346  2.863362  58.406905  67.174679  69.027709
#
#                          Weight                                     \
#          75%        max   count        mean        std         min
# 0  65.563565  73.389586  5000.0  135.860093  19.022468   64.700127
# 1  70.988744  78.998742  5000.0  187.020621  19.781155  112.902939
#
#
#           25%         50%         75%         max
# 0  122.934096  136.117583  148.810926  202.237214
# 1  173.887767  187.033546  200.357802  269.989699

# %%
gender_groupby.describe().T
# Out:
#                         0            1
# Height count  5000.000000  5000.000000
#        mean     63.708774    69.026346
#        std       2.696284     2.863362
#        min      54.263133    58.406905
#        25%      61.894441    67.174679
#        50%      63.730924    69.027709
#        75%      65.563565    70.988744
#        max      73.389586    78.998742
# Weight count  5000.000000  5000.000000
#        mean    135.860093   187.020621
#        std      19.022468    19.781155
#        min      64.700127   112.902939
#        25%     122.934096   173.887767
#        50%     136.117583   187.033546
#        75%     148.810926   200.357802
#        max     202.237214   269.989699

# %% [markdown]
# ### Distribution plots

# %% [markdown]
# #### Considering both gender and height

# %%
sns.FacetGrid(data, hue = 'Gender', height = 5)\
              .map(sns.distplot, 'Height')\
              .add_legend()
# Out:
# /Users/williamcepeda/Library/CloudStorage/OneDrive-Personal/Objectel/DataAnalytics/PS_Interpreting_Data_Descriptive_statistics/.venv/lib/python3.14/site-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /Users/williamcepeda/Library/CloudStorage/OneDrive-Personal/Objectel/DataAnalytics/PS_Interpreting_Data_Descriptive_statistics/.venv/lib/python3.14/site-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
g = sns.FacetGrid(data, hue="Gender", height=5)
g.map(sns.histplot, "Height", stat="density", common_norm=False, alpha=0.4)
g.add_legend()

# %%
g = sns.FacetGrid(data, hue="Gender", height=5)
g.map(sns.kdeplot, "Height", fill=False)
g.add_legend()

# %% [markdown]
# #### Considering both gender and weight

# %%
sns.FacetGrid(data, hue = 'Gender', height = 5)\
    .map(sns.distplot, 'Weight').add_legend()
# Out:
# /Users/williamcepeda/Library/CloudStorage/OneDrive-Personal/Objectel/DataAnalytics/PS_Interpreting_Data_Descriptive_statistics/.venv/lib/python3.14/site-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /Users/williamcepeda/Library/CloudStorage/OneDrive-Personal/Objectel/DataAnalytics/PS_Interpreting_Data_Descriptive_statistics/.venv/lib/python3.14/site-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
g = sns.FacetGrid(data, hue="Gender", height=5)
g.map(sns.histplot, "Weight", stat="density", common_norm=False, alpha=0.4)
g.add_legend()

# %%
g = sns.FacetGrid(data, hue="Gender", height=5)
g.map(sns.kdeplot, "Weight", fill=False)
g.add_legend()

# %% [markdown]
# ### Violin Plot

# %% [markdown]
# #### Gender vs Height

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(x = 'Gender', y ='Height', data = data)
# Out:
# <Axes: xlabel='Gender', ylabel='Height'>

# %% [markdown]
# #### Gender vs Weight

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(x = 'Gender', y ='Weight', data = data)
# Out:
# <Axes: xlabel='Gender', ylabel='Weight'>

# %%
plt.figure(figsize=(12, 8))

sns.violinplot(x = 'Gender', y ='Height', data = data)
# Out:
# <Axes: xlabel='Gender', ylabel='Height'>

# %%
plt.figure(figsize=(12, 8))

sns.violinplot(x = 'Gender', y ='Weight', data = data)
# Out:
# <Axes: xlabel='Gender', ylabel='Weight'>

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(data, hue = 'Gender', height = 4)
